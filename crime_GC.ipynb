# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
#crime= pd.read_csv('Crimes_-_2001_to_Present.csv')
#crime= crime[["Primary Type", "Description", "Location Description", "Arrest", "Domestic", "Year","Community Area"]]
#crime.dropna(inplace=True)
public= pd.read_csv('data/Public_Health_Statistics-_Selected_public_health_indicators_by_Chicago_community_area.csv')
#total = pd.merge(public, crime, on='Community Area')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-506ff8d0f1cc> in <module>
#       2 #crime= crime[["Primary Type", "Description", "Location Description", "Arrest", "Domestic", "Year","Community Area"]]
#       3 #crime.dropna(inplace=True)
# ----> 4 public= pd.read_csv('data/Public_Health_Statistics-_Selected_public_health_indicators_by_Chicago_community_area.csv')
#       5 #total = pd.merge(public, crime, on='Community Area')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/Public_Health_Statistics-_Selected_public_health_indicators_by_Chicago_community_area.csv does not exist: 'data/Public_Health_Statistics-_Selected_public_health_indicators_by_Chicago_community_area.csv'

# %%
public

# %%
crime
# Out:
#                        Primary Type                          Description  \
# 0                DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1               CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# 2                          BURGLARY                       UNLAWFUL ENTRY
# 3                             THEFT                            OVER $500
# 4               CRIM SEXUAL ASSAULT                       NON-AGGRAVATED
# ...                             ...                                  ...
# 1013523           CRIMINAL TRESPASS                         TO RESIDENCE
# 1013524  OFFENSE INVOLVING CHILDREN                          CHILD ABUSE
# 1013525               OTHER OFFENSE                     TELEPHONE THREAT
# 1013526                    BURGLARY                       FORCIBLE ENTRY
# 1013527             CRIMINAL DAMAGE                           TO VEHICLE
#
#                   Location Description Arrest Domestic    Year  Community Area
# 0                            RESIDENCE  False    False  2001.0            45.0
# 1                            RESIDENCE  False    False  2017.0            73.0
# 2                                OTHER  False    False  2017.0            70.0
# 3                            RESIDENCE  False    False  2017.0            42.0
# 4                          HOTEL/MOTEL  False    False  2017.0            32.0
# ...                                ...    ...      ...     ...             ...
# 1013523                      RESIDENCE  False    False  2017.0            33.0
# 1013524                      RESIDENCE   True    False  2017.0            19.0
# 1013525                      APARTMENT  False     True  2017.0            30.0
# 1013526                      RESIDENCE  False    False  2017.0            29.0
# 1013527  RESIDENTIAL YARD (FRONT/BACK)  False    False  2017.0             6.0
#
# [998719 rows x 7 columns]

# %%
total
# Out:
#         Community Area Community Area Name  Birth Rate  \
# 0                    1         Rogers Park        16.4
# 1                    1         Rogers Park        16.4
# 2                    1         Rogers Park        16.4
# 3                    1         Rogers Park        16.4
# 4                    1         Rogers Park        16.4
# ...                ...                 ...         ...
# 998706              77           Edgewater        12.1
# 998707              77           Edgewater        12.1
# 998708              77           Edgewater        12.1
# 998709              77           Edgewater        12.1
# 998710              77           Edgewater        12.1
#
#         General Fertility Rate  Low Birth Weight  \
# 0                         62.0              11.0
# 1                         62.0              11.0
# 2                         62.0              11.0
# 3                         62.0              11.0
# 4                         62.0              11.0
# ...                        ...               ...
# 998706                    48.1               7.5
# 998707                    48.1               7.5
# 998708                    48.1               7.5
# 998709                    48.1               7.5
# 998710                    48.1               7.5
#
#         Prenatal Care Beginning in First Trimester  Preterm Births  \
# 0                                             73.0            11.2
# 1                                             73.0            11.2
# 2                                             73.0            11.2
# 3                                             73.0            11.2
# 4                                             73.0            11.2
# ...                                            ...             ...
# 998706                                        76.1             7.4
# 998707                                        76.1             7.4
# 998708                                        76.1             7.4
# 998709                                        76.1             7.4
# 998710                                        76.1             7.4
#
#         Teen Birth Rate  Assault (Homicide)  Breast cancer in females  ...  \
# 0                  40.8                 7.7                      23.3  ...
# 1                  40.8                 7.7                      23.3  ...
# 2                  40.8                 7.7                      23.3  ...
# 3                  40.8                 7.7                      23.3  ...
# 4                  40.8                 7.7                      23.3  ...
# ...                 ...                 ...                       ...  ...
# 998706             15.1                 5.8                      18.5  ...
# 998707             15.1                 5.8                      18.5  ...
# 998708             15.1                 5.8                      18.5  ...
# 998709             15.1                 5.8                      18.5  ...
# 998710             15.1                 5.8                      18.5  ...
#
#         Dependency  No High School Diploma  Per Capita Income  Unemployment  \
# 0             28.8                    18.1              23714           7.5
# 1             28.8                    18.1              23714           7.5
# 2             28.8                    18.1              23714           7.5
# 3             28.8                    18.1              23714           7.5
# 4             28.8                    18.1              23714           7.5
# ...            ...                     ...                ...           ...
# 998706        23.4                     9.0              33364           9.0
# 998707        23.4                     9.0              33364           9.0
# 998708        23.4                     9.0              33364           9.0
# 998709        23.4                     9.0              33364           9.0
# 998710        23.4                     9.0              33364           9.0
#
#                    Primary Type     Description     Location Description  \
# 0                         THEFT  $500 AND UNDER                 SIDEWALK
# 1                         THEFT  $500 AND UNDER  RESIDENCE PORCH/HALLWAY
# 2                         THEFT   FROM BUILDING                APARTMENT
# 3       CRIMINAL SEXUAL ASSAULT       PREDATORY                RESIDENCE
# 4                       ASSAULT          SIMPLE                    OTHER
# ...                         ...             ...                      ...
# 998706                  ROBBERY  ARMED: HANDGUN                 SIDEWALK
# 998707                    THEFT  POCKET-PICKING            BAR OR TAVERN
# 998708                    THEFT   FROM BUILDING                RESIDENCE
# 998709                    THEFT  $500 AND UNDER  RESIDENCE PORCH/HALLWAY
# 998710          CRIMINAL DAMAGE      TO VEHICLE                    OTHER
#
#         Arrest  Domestic    Year
# 0        False     False  2017.0
# 1        False     False  2017.0
# 2        False     False  2017.0
# 3        False     False  2017.0
# 4        False     False  2007.0
# ...        ...       ...     ...
# 998706   False     False  2017.0
# 998707   False     False  2017.0
# 998708   False     False  2017.0
# 998709   False     False  2017.0
# 998710   False     False  2017.0
#
# [998711 rows x 35 columns]

# %%
y = total[(total["Year"]==2005)]
y
# Out:
#         Community Area Community Area Name  Birth Rate  \
# 59                   1         Rogers Park        16.4
# 60                   1         Rogers Park        16.4
# 63                   1         Rogers Park        16.4
# 65                   1         Rogers Park        16.4
# 96                   1         Rogers Park        16.4
# ...                ...                 ...         ...
# 992751              77           Edgewater        12.1
# 992752              77           Edgewater        12.1
# 992753              77           Edgewater        12.1
# 992754              77           Edgewater        12.1
# 992755              77           Edgewater        12.1
#
#         General Fertility Rate  Low Birth Weight  \
# 59                        62.0              11.0
# 60                        62.0              11.0
# 63                        62.0              11.0
# 65                        62.0              11.0
# 96                        62.0              11.0
# ...                        ...               ...
# 992751                    48.1               7.5
# 992752                    48.1               7.5
# 992753                    48.1               7.5
# 992754                    48.1               7.5
# 992755                    48.1               7.5
#
#         Prenatal Care Beginning in First Trimester  Preterm Births  \
# 59                                            73.0            11.2
# 60                                            73.0            11.2
# 63                                            73.0            11.2
# 65                                            73.0            11.2
# 96                                            73.0            11.2
# ...                                            ...             ...
# 992751                                        76.1             7.4
# 992752                                        76.1             7.4
# 992753                                        76.1             7.4
# 992754                                        76.1             7.4
# 992755                                        76.1             7.4
#
#         Teen Birth Rate  Assault (Homicide)  Breast cancer in females  ...  \
# 59                 40.8                 7.7                      23.3  ...
# 60                 40.8                 7.7                      23.3  ...
# 63                 40.8                 7.7                      23.3  ...
# 65                 40.8                 7.7                      23.3  ...
# 96                 40.8                 7.7                      23.3  ...
# ...                 ...                 ...                       ...  ...
# 992751             15.1                 5.8                      18.5  ...
# 992752             15.1                 5.8                      18.5  ...
# 992753             15.1                 5.8                      18.5  ...
# 992754             15.1                 5.8                      18.5  ...
# 992755             15.1                 5.8                      18.5  ...
#
#         Dependency  No High School Diploma  Per Capita Income  Unemployment  \
# 59            28.8                    18.1              23714           7.5
# 60            28.8                    18.1              23714           7.5
# 63            28.8                    18.1              23714           7.5
# 65            28.8                    18.1              23714           7.5
# 96            28.8                    18.1              23714           7.5
# ...            ...                     ...                ...           ...
# 992751        23.4                     9.0              33364           9.0
# 992752        23.4                     9.0              33364           9.0
# 992753        23.4                     9.0              33364           9.0
# 992754        23.4                     9.0              33364           9.0
# 992755        23.4                     9.0              33364           9.0
#
#               Primary Type                Description  \
# 59         CRIMINAL DAMAGE                 TO VEHICLE
# 60       CRIMINAL TRESPASS               TO RESIDENCE
# 63      DECEPTIVE PRACTICE   FRAUD OR CONFIDENCE GAME
# 65               NARCOTICS    FOUND SUSPECT NARCOTICS
# 96             SEX OFFENSE  AGG CRIMINAL SEXUAL ABUSE
# ...                    ...                        ...
# 992751             BATTERY                     SIMPLE
# 992752             BATTERY                     SIMPLE
# 992753             ROBBERY                 AGGRAVATED
# 992754             ASSAULT                     SIMPLE
# 992755             ASSAULT                     SIMPLE
#
#                    Location Description  Arrest  Domestic    Year
# 59      POLICE FACILITY/VEH PARKING LOT   False     False  2005.0
# 60         NURSING HOME/RETIREMENT HOME   False     False  2005.0
# 63                            RESIDENCE   False     False  2005.0
# 65      POLICE FACILITY/VEH PARKING LOT    True     False  2005.0
# 96                            APARTMENT   False      True  2005.0
# ...                                 ...     ...       ...     ...
# 992751                           STREET   False     False  2005.0
# 992752                           STREET    True     False  2005.0
# 992753                      GAS STATION   False     False  2005.0
# 992754                            OTHER    True     False  2005.0
# 992755                            OTHER   False     False  2005.0
#
# [4668 rows x 35 columns]

# %%
cleaned = total[(total.Year >= 2005) & (total.Year <= 2011)]
cleaned
# Out:
#         Community Area Community Area Name  Birth Rate  \
# 4                    1         Rogers Park        16.4
# 9                    1         Rogers Park        16.4
# 16                   1         Rogers Park        16.4
# 17                   1         Rogers Park        16.4
# 19                   1         Rogers Park        16.4
# ...                ...                 ...         ...
# 992823              77           Edgewater        12.1
# 992824              77           Edgewater        12.1
# 992825              77           Edgewater        12.1
# 993063              77           Edgewater        12.1
# 993657              77           Edgewater        12.1
#
#         General Fertility Rate  Low Birth Weight  \
# 4                         62.0              11.0
# 9                         62.0              11.0
# 16                        62.0              11.0
# 17                        62.0              11.0
# 19                        62.0              11.0
# ...                        ...               ...
# 992823                    48.1               7.5
# 992824                    48.1               7.5
# 992825                    48.1               7.5
# 993063                    48.1               7.5
# 993657                    48.1               7.5
#
#         Prenatal Care Beginning in First Trimester  Preterm Births  \
# 4                                             73.0            11.2
# 9                                             73.0            11.2
# 16                                            73.0            11.2
# 17                                            73.0            11.2
# 19                                            73.0            11.2
# ...                                            ...             ...
# 992823                                        76.1             7.4
# 992824                                        76.1             7.4
# 992825                                        76.1             7.4
# 993063                                        76.1             7.4
# 993657                                        76.1             7.4
#
#         Teen Birth Rate  Assault (Homicide)  Breast cancer in females  ...  \
# 4                  40.8                 7.7                      23.3  ...
# 9                  40.8                 7.7                      23.3  ...
# 16                 40.8                 7.7                      23.3  ...
# 17                 40.8                 7.7                      23.3  ...
# 19                 40.8                 7.7                      23.3  ...
# ...                 ...                 ...                       ...  ...
# 992823             15.1                 5.8                      18.5  ...
# 992824             15.1                 5.8                      18.5  ...
# 992825             15.1                 5.8                      18.5  ...
# 993063             15.1                 5.8                      18.5  ...
# 993657             15.1                 5.8                      18.5  ...
#
#         Dependency  No High School Diploma  Per Capita Income  Unemployment  \
# 4             28.8                    18.1              23714           7.5
# 9             28.8                    18.1              23714           7.5
# 16            28.8                    18.1              23714           7.5
# 17            28.8                    18.1              23714           7.5
# 19            28.8                    18.1              23714           7.5
# ...            ...                     ...                ...           ...
# 992823        23.4                     9.0              33364           9.0
# 992824        23.4                     9.0              33364           9.0
# 992825        23.4                     9.0              33364           9.0
# 993063        23.4                     9.0              33364           9.0
# 993657        23.4                     9.0              33364           9.0
#
#                       Primary Type                              Description  \
# 4                          ASSAULT                                   SIMPLE
# 9               DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 16      OFFENSE INVOLVING CHILDREN            AGG CRIM SEX ABUSE FAM MEMBER
# 17      OFFENSE INVOLVING CHILDREN            AGG CRIM SEX ABUSE FAM MEMBER
# 19             CRIM SEXUAL ASSAULT                           NON-AGGRAVATED
# ...                            ...                                      ...
# 992823                       THEFT                           $500 AND UNDER
# 992824                       THEFT                           $500 AND UNDER
# 992825                       THEFT                            FROM BUILDING
# 993063          DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 993657          DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#                 Location Description  Arrest  Domestic    Year
# 4                              OTHER   False     False  2007.0
# 9       NURSING HOME/RETIREMENT HOME   False     False  2009.0
# 16                         RESIDENCE   False     False  2008.0
# 17                         RESIDENCE   False     False  2011.0
# 19                         APARTMENT   False     False  2009.0
# ...                              ...     ...       ...     ...
# 992823                        STREET   False     False  2011.0
# 992824                        STREET   False     False  2011.0
# 992825                     APARTMENT   False     False  2011.0
# 993063                     RESIDENCE   False     False  2010.0
# 993657                     APARTMENT   False     False  2010.0
#
# [27825 rows x 35 columns]
