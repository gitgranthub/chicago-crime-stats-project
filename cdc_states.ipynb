# %% [markdown]
# # Crime_Project
# * Observations and Trends at State Level
# * Observations and Trends at Chicago

# %% [markdown]
# ### Dependencies and Setup

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
sns.set()

pd.set_option('display.max_colwidth', 30)
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Creating Function for the State Geographical location: Northern and Suthern States
def geo_state(df):
    northen_states_list = ['Alaska', 'Connecticut', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Maine', 'Massachusetts',
                       'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'New Hampshire', 'New Jersey',
                       'New York', 'North Dakota', 'Ohio', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Dakota',
                       'Vermont', 'Wisconsin', 'Wyoming']
    df['Geo']='South'
    for row in df.itertuples():
        if row.State in northen_states_list:
            df.loc[row.Index, 'Geo'] = 'North'
    return df

# %%
filter_columns = ['State_Name', 'Year', 'Population', 'House_Income', 'Per_Cap_Income', 'Pov_Rate','Unemp_Rate','Geo','Lat','Lng']
states_econ = pd.read_csv('resources/states_total.csv').filter(filter_columns)
states_econ = states_econ[(states_econ['Year'] == 2011)].filter(filter_columns)
year_econ = states_econ.groupby('Year').sum()
year_econ.head()
# Out:
#          Population  House_Income  Per_Cap_Income  Pov_Rate  Unemp_Rate  \
# Year
# 2011 306,603,772.00  2,699,586.00    1,410,965.00    686.90      208.40
#
#           Lat       Lng
# Year
# 2011 2,019.90 -4,767.31

# %%
# Import and Cleaning CDC data
states_deaths = pd.read_csv('resources/ncsh.csv')
states_deaths.drop(states_deaths[states_deaths['State']=='United States'].index, inplace=True)
states_deaths.head()
# Out:
#    Year                 113 Cause Name              Cause Name       State  \
# 1  2017  Accidents (unintentional i...  Unintentional injuries     Alabama
# 2  2017  Accidents (unintentional i...  Unintentional injuries      Alaska
# 3  2017  Accidents (unintentional i...  Unintentional injuries     Arizona
# 4  2017  Accidents (unintentional i...  Unintentional injuries    Arkansas
# 5  2017  Accidents (unintentional i...  Unintentional injuries  California
#
#    Deaths  Age-adjusted Death Rate
# 1    2703                    53.80
# 2     436                    63.70
# 3    4184                    56.20
# 4    1625                    51.80
# 5   13840                    33.20

# %%
# Creating DataSet based on number of deaths
states_deaths_tot = states_deaths.drop(['113 Cause Name', 'Age-adjusted Death Rate'], 1)
states_deaths_tot = states_deaths_tot.set_index(['Year', 'State', 'Cause Name'], drop=True).unstack('Cause Name')
states_deaths_tot.columns = states_deaths_tot.columns.get_level_values(1)
states_deaths_tot = states_deaths_tot.rename(columns={ 'State_Name':'State',
                                            "Alzheimer's disease": 'Alzheimer', 'Heart disease': 'Heart',
                                            'Influenza and pneumonia': 'Pneumonia', 'Kidney disease': 'Kidney',
                                            'Unintentional injuries': 'Injuries'})
states_deaths_tot.head()
# Out:
# Cause Name       All causes  Alzheimer   CLRD  Cancer  Diabetes  Heart  \
# Year State
# 1999 Alabama          44806        772   2179    9506      1341  13419
#      Alaska            2708         24    146     633        67    563
#      Arizona          40050        963   2553    9006      1063  10800
#      Arkansas         27925        434   1358    6137       691   8315
#      California      229380       4532  13165   53067      6401  71930
#
# Cause Name       Pneumonia  Kidney  Stroke  Suicide  Injuries
# Year State
# 1999 Alabama          1228     979    3148      555      2313
#      Alaska             46      34     171       96       294
#      Arizona          1287     544    2600      766      2214
#      Arkansas          741     458    2255      336      1287
#      California       4560    2261   17962     3077      9198

# %%
years_deaths = states_deaths_tot.groupby(states_deaths_tot.index.get_level_values(0)).sum()
years_deaths
# Out:
# Cause Name  All causes  Alzheimer    CLRD  Cancer  Diabetes   Heart  \
# Year
# 1999           2391399      44536  124181  549838     68399  725192
# 2000           2403351      49558  122009  553091     69301  710760
# 2001           2416425      53852  123013  553768     71372  700142
# 2002           2443387      58866  124816  557271     73249  696947
# 2003           2448288      63457  126382  556902     74219  685089
# 2004           2397615      65965  121987  553888     73138  652486
# 2005           2448017      71599  130933  559312     75119  652091
# 2006           2426264      72432  124583  559888     72449  631636
# 2007           2423712      74632  127924  562875     71382  616067
# 2008           2471984      82435  141090  565469     70553  616828
# 2009           2437163      79003  137353  567628     68705  599413
# 2010           2468435      83494  138080  574743     69071  597689
# 2011           2515458      84974  142943  576691     73831  596577
# 2012           2543279      83637  143489  582623     73932  599711
# 2013           2596993      84767  149205  584881     75578  611105
# 2014           2626418      93541  147101  591700     76488  614348
# 2015           2712630     110561  155041  595930     79535  633842
# 2016           2744248     116103  154596  598038     80058  635260
# 2017           2813503     121404  160201  599108     83564  647457
#
# Cause Name  Pneumonia  Kidney  Stroke  Suicide  Injuries
# Year
# 1999            63730   35525  167366    29199     97860
# 2000            65313   37251  167661    29350     97900
# 2001            62034   39480  163538    30622    101537
# 2002            65681   40974  162672    31655    106742
# 2003            65163   42453  157689    31484    109277
# 2004            59664   42480  150074    32439    112012
# 2005            63001   43901  143579    32637    117809
# 2006            56326   45344  137119    33300    121599
# 2007            52717   46448  135952    34598    123706
# 2008            56284   48237  134148    36035    121902
# 2009            53692   48935  128842    36909    118021
# 2010            50097   50476  129476    38364    120859
# 2011            53826   45591  128932    39518    126438
# 2012            50636   45622  128546    40600    127792
# 2013            56979   47112  128978    41149    130557
# 2014            55227   48146  133103    42826    135928
# 2015            57062   49959  140323    44193    146571
# 2016            51537   50046  142142    44965    161374
# 2017            55672   50633  146383    47173    169936

# %%
deaths_2011 = years_deaths[years_deaths.index == 2011]
deaths_2011
# Out:
# Cause Name  All causes  Alzheimer    CLRD  Cancer  Diabetes   Heart  \
# Year
# 2011           2515458      84974  142943  576691     73831  596577
#
# Cause Name  Pneumonia  Kidney  Stroke  Suicide  Injuries
# Year
# 2011            53826   45591  128932    39518    126438

# %%
deaths_2011_adj = deaths_2011/year_econ['Population'].values[0]*100000
deaths_2011_adj
# Out:
# Cause Name  All causes  Alzheimer  CLRD  Cancer  Diabetes  Heart  Pneumonia  \
# Year
# 2011            820.43      27.71 46.62  188.09     24.08 194.58      17.56
#
# Cause Name  Kidney  Stroke  Suicide  Injuries
# Year
# 2011         14.87   42.05    12.89     41.24

# %%
years_deaths_plot = years_deaths.drop('All causes', 1)
_=years_deaths_plot.plot(kind='barh', stacked=True, title="US Death Number by leading causes, mln", figsize=(14, 7))
plt.savefig('images/us_death_2017.png')

# %%
states_deaths_2011 = states_deaths_tot[states_deaths_tot.index.get_level_values(0)==2011]
states_deaths_2011.head()
# Out:
# Cause Name       All causes  Alzheimer   CLRD  Cancer  Diabetes  Heart  \
# Year State
# 2011 Alabama          48681       1486   2912   10233      1278  11942
#      Alaska            3849         72    194     935       107    739
#      Arizona          48381       2348   3166   10690      1740  10662
#      Arkansas         29653       1002   1985    6497       908   7168
#      California      239942      11555  13357   56449      7695  59772
#
# Cause Name       Pneumonia  Kidney  Stroke  Suicide  Injuries
# Year State
# 2011 Alabama           951    1047    2568      654      2662
#      Alaska             58      53     168      143       385
#      Arizona           690     395    2148     1160      3096
#      Arkansas          727     787    1692      462      1510
#      California       6200    2599   13503     3996     10824

# %%
states_deaths_2011.columns
# Out:
# Index(['All causes', 'Alzheimer', 'CLRD', 'Cancer', 'Diabetes', 'Heart',
#        'Pneumonia', 'Kidney', 'Stroke', 'Suicide', 'Injuries'],
#       dtype='object', name='Cause Name')

# %%
states_deaths_2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 51 entries, (2011, 'Alabama') to (2011, 'Wyoming')
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   All causes  51 non-null     int64
#  1   Alzheimer   51 non-null     int64
#  2   CLRD        51 non-null     int64
#  3   Cancer      51 non-null     int64
#  4   Diabetes    51 non-null     int64
#  5   Heart       51 non-null     int64
#  6   Pneumonia   51 non-null     int64
#  7   Kidney      51 non-null     int64
#  8   Stroke      51 non-null     int64
#  9   Suicide     51 non-null     int64
#  10  Injuries    51 non-null     int64
# dtypes: int64(11)
# memory usage: 5.2+ KB

# %%
for column in states_deaths_2011.columns:
    states_deaths_2011[column] = states_deaths_2011[column].values/(states_econ['Population'].values)*100000

# %%
states_deaths_2011.head()
# Out:
# Cause Name       All causes  Alzheimer  CLRD  Cancer  Diabetes  Heart  \
# Year State
# 2011 Alabama       1,025.42      31.30 61.34  215.55     26.92 251.55
#      Alaska          549.31      10.28 27.69  133.44     15.27 105.47
#      Arizona         763.42      37.05 49.96  168.68     27.46 168.24
#      Arkansas      1,023.96      34.60 68.54  224.35     31.35 247.52
#      California      649.03      31.26 36.13  152.69     20.81 161.68
#
# Cause Name       Pneumonia  Kidney  Stroke  Suicide  Injuries
# Year State
# 2011 Alabama         20.03   22.05   54.09    13.78     56.07
#      Alaska           8.28    7.56   23.98    20.41     54.94
#      Arizona         10.89    6.23   33.89    18.30     48.85
#      Arkansas        25.10   27.18   58.43    15.95     52.14
#      California      16.77    7.03   36.52    10.81     29.28

# %%
states_deaths_2011['State'] = states_deaths_2011.index.get_level_values(1)
states_deaths_2011 = geo_state(states_deaths_2011)
# states_deaths_2011 = states_deaths_2011.drop('State',1)
states_deaths_2011.head()
# Out:
# Cause Name       All causes  Alzheimer  CLRD  Cancer  Diabetes  Heart  \
# Year State
# 2011 Alabama       1,025.42      31.30 61.34  215.55     26.92 251.55
#      Alaska          549.31      10.28 27.69  133.44     15.27 105.47
#      Arizona         763.42      37.05 49.96  168.68     27.46 168.24
#      Arkansas      1,023.96      34.60 68.54  224.35     31.35 247.52
#      California      649.03      31.26 36.13  152.69     20.81 161.68
#
# Cause Name       Pneumonia  Kidney  Stroke  Suicide  Injuries       State  \
# Year State
# 2011 Alabama         20.03   22.05   54.09    13.78     56.07     Alabama
#      Alaska           8.28    7.56   23.98    20.41     54.94      Alaska
#      Arizona         10.89    6.23   33.89    18.30     48.85     Arizona
#      Arkansas        25.10   27.18   58.43    15.95     52.14    Arkansas
#      California      16.77    7.03   36.52    10.81     29.28  California
#
# Cause Name         Geo
# Year State
# 2011 Alabama     South
#      Alaska      North
#      Arizona     South
#      Arkansas    South
#      California  South

# %%
data_plot = states_deaths_2011[['All causes', 'Geo']]
_=sns.scatterplot(states_deaths_2011['All causes'], states_deaths_2011['Suicide'], data = states_deaths_2011, hue='Geo')

# %%
states_deaths_2011.to_csv("resources/cdc_analysis.csv", encoding="utf-8", index=False)
