# %%
# %matplotlib
import gmaps
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import os
import pandas as pd
pd.options.display.max_columns = None
import requests
import time
from scipy.stats import linregress, pearsonr
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import statsmodels.formula.api as smf
#from sklearn.decomposition import FactorAnalysis
# Out:
# Using matplotlib backend: Qt5Agg

# %%
#Accessing full neighborhood dataset, which was derived from two data sets (Neighborhood_Health.csv and Reported_Crimes.csv) and neighborhood_crime.ipynb

z = pd.read_csv('output_data/neighborhood_full_data.csv')

# Index(['Community Area Name', 'Community Area', 'Birth Rate',
#        'General Fertility Rate', 'Low Birth Weight',
#        'Prenatal Care Beginning in First Trimester', 'Preterm Births',
#        'Teen Birth Rate', 'Homicide_rate_per_100k', 'Breast cancer in females',
#        'Cancer (All Sites)', 'Colorectal Cancer', 'Diabetes-related',
#        'Firearm-related', 'Infant Mortality Rate', 'Lung Cancer',
#        'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)',
#        'Childhood Blood Lead Level Screening', 'Childhood Lead Poisoning',
#        'Gonorrhea in Females', 'Tuberculosis', 'Below Poverty Level',
#        'Crowded Housing', 'Dependency', 'No High School Diploma',
#        'Per Capita Income', 'Unemployment', 'ASSAULT', 'DECEPTIVE PRACTICE',
#        'OFFENSE INVOLVING CHILDREN', 'CRIM SEXUAL ASSAULT', 'CRIMINAL DAMAGE',
#        'CRIMINAL TRESPASS', 'WEAPONS VIOLATION', 'MOTOR VEHICLE THEFT',
#        'NARCOTICS', 'THEFT', 'BATTERY', 'OTHER OFFENSE', 'ROBBERY',
#        'PUBLIC PEACE VIOLATION', 'SEX OFFENSE', 'PROSTITUTION', 'BURGLARY',
#        'STALKING', 'CRIMINAL SEXUAL ASSAULT', 'ARSON', 'Homicide', 'GAMBLING',
#        'KIDNAPPING', 'INTERFERENCE WITH PUBLIC OFFICER', 'INTIMIDATION',
#        'LIQUOR LAW VIOLATION', 'OBSCENITY', 'PUBLIC INDECENCY',
#        'OTHER NARCOTIC VIOLATION', 'NON-CRIMINAL', 'HUMAN TRAFFICKING',
#        'RITUALISM', 'Violence', 'Sexual Crimes', 'Property Crimes', 'Drugs'],
#       dtype='object')

# 77 rows × 64 columns

# %%
# Variable Units

# Per Capita Income, Birth Rate per (1k),
# General Fertility Rate per (1k),% Low Birth Weight,% Prenatal Care in First Trimester,
# % Preterm Births,Teen Birth Rate per (1k),Homicides per (100k),Breast Cancer Females per (100k),
# Cancer (All Sites) per (100k),Colorectal Cancer per (100k),Diabetes-related per (100k),Firearm-related per (100k),
# Infant Mortality Rate per (1k),Lung Cancer per (100k),Prostate Cancer in Males per (100k),
# Stroke (Cerebrovascular Disease) per (100k),Childhood Blood Lead Level Screening per (1k),
# Childhood Lead Poisoning per (100),Gonorrhea in Females per (100k),Gonorrhea in Males per (100k),
# Tuberculosis per (100k),% Below Poverty Level,% Crowded Housing,% Dependency,% No High School Diploma,Unemployment

# %%
# Removing any crime that is not homicide, violence, or property crimes from dataframe for consistency with state-level analysis

z = z[['Community Area Name', 'Homicide', 'Homicide_rate_per_100k', 'Violence', 'Property Crimes', 'Birth Rate',
       'General Fertility Rate', 'Low Birth Weight',
       'Prenatal Care Beginning in First Trimester', 'Preterm Births',
       'Teen Birth Rate', 'Breast cancer in females',
       'Cancer (All Sites)', 'Colorectal Cancer', 'Diabetes-related',
       'Firearm-related', 'Infant Mortality Rate', 'Lung Cancer',
       'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)',
       'Childhood Blood Lead Level Screening', 'Childhood Lead Poisoning',
       'Gonorrhea in Females', 'Tuberculosis', 'Below Poverty Level',
       'Crowded Housing', 'Dependency', 'No High School Diploma',
       'Per Capita Income', 'Unemployment']].reset_index(drop=True)

# 77 rows × 30 columns

# %%
# Selecting variables that correlate highly (r >= 0.3) with homicide
#Categorizing variables: crime factors, disease factors, birth factors, and economic factors

"""
Variables are selected for further analysis if over a 0.3 pearson correlation with any crime factor
(i.e., 'Homicide', 'Violence', or 'Property Crimes') and statistically significant as indicated by
a two-tailed t-test (p < 0.5).
"""

# Crime Factors
ys = ['Homicide', 'Violence', 'Property Crimes']

# Disease Factors
print('Disease Factors')
xsd = ['Breast cancer in females',
       'Cancer (All Sites)', 'Colorectal Cancer', 'Diabetes-related', 'Lung Cancer',\
       'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)', 'Tuberculosis']
disease_factors = []
for y in ys:
    for x in xsd:
        coefficient, p_value = pearsonr(z[x], z[y])
        if coefficient >= 0.3 and p_value <= .05:
            print(f'x={y}, y={x}, r={coefficient}, p={p_value}')
            if x not in disease_factors:
                disease_factors.append(x)
print()
print(disease_factors)
print()

#Birth Factors
print('Birth Factors')
xsb = ['Birth Rate','General Fertility Rate', 'Low Birth Weight', 'Prenatal Care Beginning in First Trimester', 'Preterm Births','Teen Birth Rate']
birth_problems = []
for y in ys:
    for x in xsb:
        coefficient, p_value = pearsonr(z[x], z[y])
        if coefficient >= 0.3 and p_value <= .05:
            print(f'x={y}, y={x}, r={coefficient}, p={p_value}')
            if x not in birth_problems:
                birth_problems.append(x)
print()
print(birth_problems)
print()

#Economic Factors
print('Economic Factors')
xse = ['Below Poverty Level', 'Crowded Housing', 'Dependency', 'No High School Diploma', 'Per Capita Income', 'Unemployment']
economic_factors = []
for y in ys:
    for x in xse:
        coefficient, p_value = pearsonr(z[x], z[y])
        if coefficient >= 0.3 and p_value <= .05:
            print(f'x={y}, y={x}, r={coefficient}, p={p_value}')
            if x not in economic_factors:
                economic_factors.append(x)
print()
print(economic_factors)
print()
# Out:
# Disease Factors
# x=Homicide, y=Breast cancer in females, r=0.404349454435313, p=0.00026513954541516465
# x=Homicide, y=Cancer (All Sites), r=0.5342987330417479, p=5.593499116873891e-07
# x=Homicide, y=Colorectal Cancer, r=0.3997293860331488, p=0.00031623644381903584
# x=Homicide, y=Diabetes-related, r=0.5479774592764278, p=2.4922022604025977e-07
# x=Homicide, y=Lung Cancer, r=0.370443643411419, p=0.000912222378386188
# x=Homicide, y=Prostate Cancer in Males, r=0.5234656183753, p=1.0350732704160641e-06
# x=Homicide, y=Stroke (Cerebrovascular Disease), r=0.41801644280939265, p=0.00015504848981248896
# x=Violence, y=Breast cancer in females, r=0.3585250208956884, p=0.0013660005483273113
# x=Violence, y=Cancer (All Sites), r=0.44730476075227643, p=4.532536917172316e-05
# x=Violence, y=Colorectal Cancer, r=0.32814190285202566, p=0.0035743565377889487
# x=Violence, y=Diabetes-related, r=0.47160952400069905, p=1.4945367027873454e-05
# x=Violence, y=Lung Cancer, r=0.31138238679510577, p=0.005841172483964133
# x=Violence, y=Prostate Cancer in Males, r=0.4321738216703671, p=8.677036540853363e-05
#
# ['Breast cancer in females', 'Cancer (All Sites)', 'Colorectal Cancer', 'Diabetes-related', 'Lung Cancer', 'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)']
#
# Birth Factors
# x=Homicide, y=Birth Rate, r=0.43667097034534663, p=7.176836611343093e-05
# x=Homicide, y=General Fertility Rate, r=0.43111132195596125, p=9.071520321297802e-05
# x=Homicide, y=Low Birth Weight, r=0.5352097584636112, p=5.306142123866068e-07
# x=Homicide, y=Preterm Births, r=0.46130432106246283, p=2.416999635370305e-05
# x=Homicide, y=Teen Birth Rate, r=0.7274609080962497, p=6.724447431689061e-14
# x=Violence, y=Birth Rate, r=0.37109858970764453, p=0.0008918063265255091
# x=Violence, y=Low Birth Weight, r=0.45816776018370303, p=2.7893105722247646e-05
# x=Violence, y=Preterm Births, r=0.36351164432193406, p=0.0011558380071673994
# x=Violence, y=Teen Birth Rate, r=0.6236592979622526, p=1.3721717784874644e-09
#
# ['Birth Rate', 'General Fertility Rate', 'Low Birth Weight', 'Preterm Births', 'Teen Birth Rate']
#
# Economic Factors
# x=Homicide, y=Below Poverty Level, r=0.4990947799177039, p=3.833342867359773e-06
# x=Homicide, y=Dependency, r=0.3161893262566225, p=0.005087738175821125
# x=Homicide, y=Unemployment, r=0.4775503834149683, p=1.1247600995314497e-05
# x=Violence, y=Below Poverty Level, r=0.41728556099987335, p=0.00015965481255266617
# x=Violence, y=Unemployment, r=0.36315317351855264, p=0.0011699068414184003
#
# ['Below Poverty Level', 'Dependency', 'Unemployment']

# %%
z.loc[:,'Homicide': 'Property Crimes', ].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col1 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col2 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col3 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col0 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col1 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col3 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col0 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col2 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Homicide</th>        <th class="col_heading level0 col1" >Homicide_rate_per_100k</th>        <th class="col_heading level0 col2" >Violence</th>        <th class="col_heading level0 col3" >Property Crimes</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9blevel0_row0" class="row_heading level0 row0" >Homicide</th>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col1" class="data row0 col1" >0.633506</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col2" class="data row0 col2" >0.948805</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow0_col3" class="data row0 col3" >0.639770</td>
#             </tr>
#             <tr>
#                         <th id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9blevel0_row1" class="row_heading level0 row1" >Homicide_rate_per_100k</th>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col0" class="data row1 col0" >0.633506</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col2" class="data row1 col2" >0.512642</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow1_col3" class="data row1 col3" >0.163880</td>
#             </tr>
#             <tr>
#                         <th id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9blevel0_row2" class="row_heading level0 row2" >Violence</th>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col0" class="data row2 col0" >0.948805</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col1" class="data row2 col1" >0.512642</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow2_col3" class="data row2 col3" >0.800967</td>
#             </tr>
#             <tr>
#                         <th id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9blevel0_row3" class="row_heading level0 row3" >Property Crimes</th>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col0" class="data row3 col0" >0.639770</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col1" class="data row3 col1" >0.163880</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col2" class="data row3 col2" >0.800967</td>
#                         <td id="T_348ca2ec_d06d_11ea_ac79_484520bb7f9brow3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
#Creating strong correlates csv file

strong_correlates = z[['Community Area Name', 'Homicide_rate_per_100k'] + ys + disease_factors + birth_problems + economic_factors]
strong_correlates.to_csv('output_data/analysis_data.csv', index=None)

# 77 rows × 19 columns

strong_correlates.describe()
# Out:
#        Homicide_rate_per_100k    Homicide      Violence  Property Crimes  \
# count               77.000000   77.000000     77.000000        77.000000
# mean                18.068831   41.922078   9030.376623     13073.883117
# std                 16.561077   48.766837   8336.806512     10438.963028
# min                  0.000000    0.000000    623.000000       898.000000
# 25%                  4.900000    9.000000   3071.000000      4869.000000
# 50%                 10.800000   21.000000   6165.000000      9661.000000
# 75%                 32.200000   59.000000  13119.000000     17936.000000
# max                 70.300000  238.000000  46833.000000     46262.000000
#
#        Breast cancer in females  Cancer (All Sites)  Colorectal Cancer  \
# count                 77.000000           77.000000          77.000000
# mean                  25.951948          194.277922          21.584416
# std                    9.557590           45.652058           7.695335
# min                    7.600000          120.100000           8.600000
# 25%                   20.200000          152.900000          15.100000
# 50%                   24.000000          189.400000          21.900000
# 75%                   32.700000          235.200000          27.100000
# max                   54.700000          291.500000          39.400000
#
#        Diabetes-related  Lung Cancer  Prostate Cancer in Males  \
# count         77.000000    77.000000                 77.000000
# mean          71.937662    51.481818                 36.805195
# std           21.497999    16.439928                 20.595189
# min           26.800000    15.900000                  0.000000
# 25%           58.600000    37.700000                 19.700000
# 50%           73.000000    50.000000                 32.100000
# 75%           83.900000    63.800000                 51.400000
# max          119.100000    89.600000                 92.900000
#
#        Stroke (Cerebrovascular Disease)  Birth Rate  General Fertility Rate  \
# count                         77.000000   77.000000               77.000000
# mean                          46.544156   15.698701               68.394805
# std                           14.448570    3.528735               15.257465
# min                           22.000000    9.400000               27.700000
# 25%                           37.900000   12.900000               60.100000
# 50%                           43.100000   15.700000               68.300000
# 75%                           53.500000   18.500000               80.700000
# max                           99.100000   22.400000               94.900000
#
#        Low Birth Weight  Preterm Births  Teen Birth Rate  Below Poverty Level  \
# count         77.000000       77.000000        77.000000            77.000000
# mean          10.101299       11.264935        50.064935            20.292208
# std            3.913926        3.016916        28.097817            11.496988
# min            3.500000        5.000000         1.300000             3.100000
# 25%            7.300000        8.800000        33.700000            12.000000
# 50%            8.700000       10.800000        49.200000            18.200000
# 75%           12.700000       13.700000        67.900000            26.100000
# max           19.700000       17.500000       116.900000            61.400000
#
#        Dependency  Unemployment
# count   77.000000     77.000000
# mean    35.829870     13.303896
# std      7.269802      7.031965
# min     15.500000      4.200000
# 25%     32.300000      7.800000
# 50%     38.300000     11.500000
# 75%     40.900000     17.400000
# max     50.200000     40.000000

# %%
strong_correlates.columns
# Out:
# Index(['Community Area Name', 'Homicide_rate_per_100k', 'Homicide', 'Violence',
#        'Property Crimes', 'Breast cancer in females', 'Cancer (All Sites)',
#        'Colorectal Cancer', 'Diabetes-related', 'Lung Cancer',
#        'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)',
#        'Birth Rate', 'General Fertility Rate', 'Low Birth Weight',
#        'Preterm Births', 'Teen Birth Rate', 'Below Poverty Level',
#        'Dependency', 'Unemployment'],
#       dtype='object')

# %%
health_factors = strong_correlates[['Homicide_rate_per_100k', 'Breast cancer in females', 'Cancer (All Sites)',
       'Colorectal Cancer', 'Diabetes-related', 'Lung Cancer', 'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)']]

health_factors.columns = ['Homicide (per 100k)', 'Breast Cancer', 'Cancer (All Sites)', 'Colorectal Cancer',\
                                 'Diabetes-related', 'Lung Cancer', 'Prostate Cancer', 'Stroke']

health_factors.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col3 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col4 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col6 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow0_col7 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col0 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col1 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col3 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col4 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col5 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col6 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow2_col7 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col0 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col2 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col4 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col5 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col6 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow3_col7 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col0 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col5 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col6 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow4_col7 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col3 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col4 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col6 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow5_col7 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col0 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col2 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col4 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col5 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow6_col7 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow7_col0 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow7_col2 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_40aef334_d06d_11ea_b3a5_484520bb7f9brow7_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;

# %%
birth_factors = strong_correlates[['Homicide_rate_per_100k',
       'Birth Rate', 'General Fertility Rate', 'Low Birth Weight',
       'Preterm Births', 'Teen Birth Rate']].reset_index(drop=True)


birth_factors.rename(columns={'Homicide_rate_per_100k': 'Homicide (per 100k)'}, inplace=True)

birth_factors.corr()
# Out:
#                         Homicide (per 100k)  Birth Rate  \
# Homicide (per 100k)                1.000000    0.188536
# Birth Rate                         0.188536    1.000000
# General Fertility Rate             0.293843    0.810334
# Low Birth Weight                   0.747493    0.108179
# Preterm Births                     0.742019    0.004334
# Teen Birth Rate                    0.768307    0.612710
#
#                         General Fertility Rate  Low Birth Weight  \
# Homicide (per 100k)                   0.293843          0.747493
# Birth Rate                            0.810334          0.108179
# General Fertility Rate                1.000000          0.142189
# Low Birth Weight                      0.142189          1.000000
# Preterm Births                        0.122235          0.843100
# Teen Birth Rate                       0.655528          0.622936
#
#                         Preterm Births  Teen Birth Rate
# Homicide (per 100k)           0.742019         0.768307
# Birth Rate                    0.004334         0.612710
# General Fertility Rate        0.122235         0.655528
# Low Birth Weight              0.843100         0.622936
# Preterm Births                1.000000         0.549843
# Teen Birth Rate               0.549843         1.000000

# %%
economic_factors = strong_correlates[['Homicide_rate_per_100k','Below Poverty Level','Dependency', 'Unemployment']].reset_index(drop=True)
economic_factors.rename(columns={'Homicide_rate_per_100k': 'Homicide (per 100k)'}, inplace=True)
economic_factors.corr().corr().style.background_gradient('BrBG')
# Out:
# <style  type="text/css" >
#     #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col0 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col1 {
#             background-color:  #d4ede9;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col2 {
#             background-color:  #d3aa5f;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col3 {
#             background-color:  #61b7ac;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col0 {
#             background-color:  #f6ebcd;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col1 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col2 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col3 {
#             background-color:  #8fd3c9;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col0 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col1 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col2 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col3 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col0 {
#             background-color:  #70c1b6;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col1 {
#             background-color:  #61b7ac;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col2 {
#             background-color:  #bf812d;
#             color:  #000000;
#         }    #T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col3 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }</style><table id="T_4845f286_d06d_11ea_8dcc_484520bb7f9b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Homicide (per 100k)</th>        <th class="col_heading level0 col1" >Below Poverty Level</th>        <th class="col_heading level0 col2" >Dependency</th>        <th class="col_heading level0 col3" >Unemployment</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4845f286_d06d_11ea_8dcc_484520bb7f9blevel0_row0" class="row_heading level0 row0" >Homicide (per 100k)</th>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col1" class="data row0 col1" >0.166107</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col2" class="data row0 col2" >-0.441106</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow0_col3" class="data row0 col3" >0.596215</td>
#             </tr>
#             <tr>
#                         <th id="T_4845f286_d06d_11ea_8dcc_484520bb7f9blevel0_row1" class="row_heading level0 row1" >Below Poverty Level</th>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col0" class="data row1 col0" >0.166107</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col2" class="data row1 col2" >-0.954319</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow1_col3" class="data row1 col3" >0.494276</td>
#             </tr>
#             <tr>
#                         <th id="T_4845f286_d06d_11ea_8dcc_484520bb7f9blevel0_row2" class="row_heading level0 row2" >Dependency</th>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col0" class="data row2 col0" >-0.441106</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col1" class="data row2 col1" >-0.954319</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow2_col3" class="data row2 col3" >-0.562269</td>
#             </tr>
#             <tr>
#                         <th id="T_4845f286_d06d_11ea_8dcc_484520bb7f9blevel0_row3" class="row_heading level0 row3" >Unemployment</th>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col0" class="data row3 col0" >0.596215</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col1" class="data row3 col1" >0.494276</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col2" class="data row3 col2" >-0.562269</td>
#                         <td id="T_4845f286_d06d_11ea_8dcc_484520bb7f9brow3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# Function for Simple Regression

# Features: plots line, provides stats, describes relationship

def regression(x, y, x_label, y_label):
    title = f'{x_label} predicting {y_label}'
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    title = title.replace('\n', '_').replace(' ', '_')
    plt.savefig(f'output_data/{title}.png')
    plt.show()
    plt.close()
    print(line_eq)
    print()
    r = pearsonr(x, y)[0]
    p = pearsonr(x, y)[1]
    print(f"r = {r:.2f}, p = {p:.4f}, r_squared = {rvalue**2:.2f}")
    print()
    if p > 0.05:
        print(f'There is no relationship between {x_label.lower()} and {y_label.lower()}, p > 0.05.')
    else:
        if r > 0:
            explanation = f'An increase in {x_label.lower()} is associated with an increase in {y_label.lower()}.'
            direction = 'positive'
            if r >= 0.6:
                strength = 'strong'
            elif r >= 0.3:
                strength = 'moderate'
            else:
                strength = 'weak'
        else:
            direction = 'negative'
            explanation = f'An increase in {x_label.lower()} is associated with a decrease in {y_label.lower()}.'
            if r <= -0.6:
                strength = 'strong'
            elif r <= -0.3:
                strength = 'moderate'
            else:
                strength = 'weak'       
        print(f'There is a {strength} {direction} relationship between {x_label.lower()} and {y_label.lower()}, p > 0.05.')
        print(explanation)
    print()

# %%
# Multiple Regression Function

# Features: Provides stats and statistical model test

def multiple_regression(xs, y): # xs is a dataframe, y is a series; prints output and returns predictions
    xs = sm.add_constant(xs) # adding a constant
    model = sm.OLS(y, xs).fit()
    predictions = model.predict(xs) 
    print_model = model.summary()
    print(print_model)
    return predictions

# %%
#Multiple Regression: Regressing Neighborhood Homicide on Disease Factors

xs = strong_correlates[['Cancer (All Sites)','Colorectal Cancer', 'Diabetes-related', 'Lung Cancer','Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)']]
y = strong_correlates['Homicide']

multiple_regression(xs, y)

# Analysis finds significant results, but has potential multicollinearity issues

# Prostrate Cancer and Stroke were the only signficant regression coefficients.

# N = 77

#Sig factors were lung cancer & Cancer (All Sites)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Homicide   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.361
# Method:                 Least Squares   F-statistic:                     8.146
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):           1.09e-06
# Time:                        19:57:24   Log-Likelihood:                -387.67
# No. Observations:                  77   AIC:                             789.3
# Df Residuals:                      70   BIC:                             805.7
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              -80.9292     26.926     -3.006      0.004    -134.631     -27.227
# Cancer (All Sites)                   0.7813      0.331      2.359      0.021       0.121       1.442
# Colorectal Cancer                   -0.3622      1.000     -0.362      0.718      -2.357       1.633
# Diabetes-related                     0.5461      0.334      1.633      0.107      -0.121       1.213
# Lung Cancer                         -1.7916      0.671     -2.668      0.009      -3.131      -0.452
# Prostate Cancer in Males             0.4088      0.399      1.024      0.309      -0.387       1.205
# Stroke (Cerebrovascular Disease)     0.3606      0.497      0.726      0.470      -0.630       1.351
# ==============================================================================
# Omnibus:                       16.827   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.818
# Skew:                           0.909   Prob(JB):                     6.73e-06
# Kurtosis:                       5.029   Cond. No.                     1.39e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0     29.227726
# 1     17.301870
# 2    -15.109483
# 3     56.478757
# 4     69.826547
#         ...
# 72    18.179161
# 73    66.694147
# 74    21.469027
# 75    51.783621
# 76    64.068735
# Length: 77, dtype: float64

# %%
#Multiple Regression: Regressing Neighborhood Homicide Rate (per 100k) on Disease Factors

xs = strong_correlates[['Cancer (All Sites)','Colorectal Cancer', 'Diabetes-related', 'Lung Cancer','Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)']]
y = strong_correlates['Homicide_rate_per_100k']

multiple_regression(xs, y)

# Analysis finds significant results, but has potential multicollinearity issues

# Prostrate Cancer and Stroke were the only signficant regression coefficients.

# N = 77

#Sig factors: Prostate Cancer in Males & Stroke (Cerebrovascular Disease)
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Homicide_rate_per_100k   R-squared:                       0.729
# Model:                                OLS   Adj. R-squared:                  0.706
# Method:                     Least Squares   F-statistic:                     31.41
# Date:                    Mon, 27 Jul 2020   Prob (F-statistic):           5.05e-18
# Time:                            19:57:29   Log-Likelihood:                -274.61
# No. Observations:                      77   AIC:                             563.2
# Df Residuals:                          70   BIC:                             579.6
# Df Model:                               6
# Covariance Type:                nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              -27.9617      6.201     -4.509      0.000     -40.330     -15.593
# Cancer (All Sites)                   0.0151      0.076      0.198      0.844      -0.137       0.167
# Colorectal Cancer                    0.3053      0.230      1.325      0.189      -0.154       0.765
# Diabetes-related                     0.0983      0.077      1.276      0.206      -0.055       0.252
# Lung Cancer                         -0.0234      0.155     -0.151      0.880      -0.332       0.285
# Prostate Cancer in Males             0.2247      0.092      2.445      0.017       0.041       0.408
# Stroke (Cerebrovascular Disease)     0.4807      0.114      4.202      0.000       0.253       0.709
# ==============================================================================
# Omnibus:                        9.217   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               13.646
# Skew:                          -0.441   Prob(JB):                      0.00109
# Kurtosis:                       4.864   Cond. No.                     1.39e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0      7.514723
# 1      7.488305
# 2      6.923713
# 3     21.646169
# 4     30.272844
#         ...
# 72     9.351363
# 73    37.176332
# 74     4.647166
# 75     7.542766
# 76    31.285998
# Length: 77, dtype: float64

# %%
#Multiple Regression: Regressing Neighboord Homicide on Birth Factors

# % of low birth rate, % of preterm births, teen birth rate per 1,000
xs = strong_correlates[['Low Birth Weight', 'Preterm Births', 'Teen Birth Rate']]
y = strong_correlates['Homicide']

multiple_regression(xs, y)

# 

# N = 77

# Sig Factor: Teen Birth Rate
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Homicide   R-squared:                       0.540
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     28.60
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):           2.45e-12
# Time:                        19:57:33   Log-Likelihood:                -378.13
# No. Observations:                  77   AIC:                             764.3
# Df Residuals:                      73   BIC:                             773.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -29.3841     15.501     -1.896      0.062     -60.277       1.509
# Low Birth Weight     1.8758      1.967      0.954      0.343      -2.044       5.795
# Preterm Births      -0.3254      2.389     -0.136      0.892      -5.087       4.437
# Teen Birth Rate      1.1190      0.176      6.345      0.000       0.768       1.471
# ==============================================================================
# Omnibus:                       32.223   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.846
# Skew:                           1.320   Prob(JB):                     5.10e-20
# Kurtosis:                       7.552   Cond. No.                         240.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     33.655915
# 1     39.968258
# 2      8.163716
# 3     26.679518
# 4     80.843182
#         ...
# 72    32.079634
# 73    69.749244
# 74    16.567696
# 75    39.227287
# 76    55.132460
# Length: 77, dtype: float64

# %%
#Multiple Regression: Regressing Neighboord Homicide Rate (per 100k) on Birth Factors

# % of low birth rate, % of preterm births, teen birth rate per 1,000
xs = strong_correlates[['Low Birth Weight', 'Preterm Births', 'Teen Birth Rate']]
y = strong_correlates['Homicide_rate_per_100k']

multiple_regression(xs, y)

# 

# N = 77

# Sig factors: Teen Birth Rate & Preterm Births
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Homicide_rate_per_100k   R-squared:                       0.743
# Model:                                OLS   Adj. R-squared:                  0.732
# Method:                     Least Squares   F-statistic:                     70.30
# Date:                    Mon, 27 Jul 2020   Prob (F-statistic):           1.76e-21
# Time:                            19:57:36   Log-Likelihood:                -272.61
# No. Observations:                      77   AIC:                             553.2
# Df Residuals:                          73   BIC:                             562.6
# Df Model:                               3
# Covariance Type:                nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -24.1852      3.937     -6.143      0.000     -32.032     -16.339
# Low Birth Weight     0.6628      0.499      1.327      0.189      -0.333       1.658
# Preterm Births       1.8975      0.607      3.127      0.003       0.688       3.107
# Teen Birth Rate      0.2833      0.045      6.325      0.000       0.194       0.373
# ==============================================================================
# Omnibus:                       54.164   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              298.723
# Skew:                           2.031   Prob(JB):                     1.36e-65
# Kurtosis:                      11.752   Cond. No.                         240.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0      9.804957
# 1     14.806473
# 2     11.013289
# 3     14.072313
# 4     33.421392
#         ...
# 72     9.236795
# 73    32.222612
# 74     5.403495
# 75    16.277939
# 76    32.753481
# Length: 77, dtype: float64

# %%
#Multiple Regression: Regressing Homicide on Economic Factors

xs = strong_correlates[['Below Poverty Level', 'Dependency', 'Unemployment']]
y = strong_correlates['Homicide']

multiple_regression(xs, y)

# Sig Factor: Below Poverty Level
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Homicide   R-squared:                       0.275
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     9.225
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):           3.00e-05
# Time:                        19:57:38   Log-Likelihood:                -395.68
# No. Observations:                  77   AIC:                             799.4
# Df Residuals:                      73   BIC:                             808.7
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 -21.1735     25.849     -0.819      0.415     -72.691      30.344
# Below Poverty Level     1.4142      0.660      2.144      0.035       0.100       2.729
# Dependency              0.5029      0.846      0.595      0.554      -1.182       2.188
# Unemployment            1.2312      1.241      0.992      0.324      -1.241       3.704
# ==============================================================================
# Omnibus:                       24.109   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.376
# Skew:                           0.971   Prob(JB):                     4.70e-14
# Kurtosis:                       6.919   Cond. No.                         240.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     30.232872
# 1     35.061478
# 2     62.795982
# 3     21.552159
# 4     64.441589
#         ...
# 72    31.138163
# 73    55.344080
# 74    29.168055
# 75    19.932717
# 76    59.056878
# Length: 77, dtype: float64

# %%
#Multiple Regression: Regressing Homicide_rate_per_100k on Economic Factors

xs = strong_correlates[['Below Poverty Level', 'Dependency', 'Unemployment']]
y = strong_correlates['Homicide_rate_per_100k']

multiple_regression(xs, y)

# Sig factor: Unemployment
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Homicide_rate_per_100k   R-squared:                       0.681
# Model:                                OLS   Adj. R-squared:                  0.668
# Method:                     Least Squares   F-statistic:                     52.01
# Date:                    Mon, 27 Jul 2020   Prob (F-statistic):           4.29e-18
# Time:                            19:57:42   Log-Likelihood:                -280.88
# No. Observations:                      77   AIC:                             569.8
# Df Residuals:                          73   BIC:                             579.1
# Df Model:                               3
# Covariance Type:                nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 -17.0002      5.820     -2.921      0.005     -28.600      -5.401
# Below Poverty Level     0.1845      0.149      1.242      0.218      -0.112       0.480
# Dependency              0.3221      0.190      1.692      0.095      -0.057       0.702
# Unemployment            1.4872      0.279      5.324      0.000       0.931       2.044
# ==============================================================================
# Omnibus:                       15.627   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.342
# Skew:                           0.811   Prob(JB):                     8.54e-06
# Kurtosis:                       5.154   Cond. No.                         240.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0      9.877841
# 1     19.560501
# 2     19.062191
# 3      9.660002
# 4     37.069365
#         ...
# 72    10.917498
# 73    26.356720
# 74     9.869848
# 75     2.194825
# 76    26.059198
# Length: 77, dtype: float64

# %%
# 3D Visualization of Multiple Regression Function
def regression_3d_visualization(dataframe, x1, x2, y, size = (10,10), x1label='X Label', x2label='Y Label', ylabel='Z Label'):
    df = dataframe[[x1, x2, y]].reset_index(drop=True)
    x1r, x2r, yr = x1, x2, y
    if ' ' in x1:
        x1r = x1.replace(' ', '')
        df.rename(columns={x1: x1r}, inplace=True)
    if ' ' in x2:
        x2r = x2.replace(' ', '')
        df.rename(columns={x2: x2r}, inplace=True)
    if ' ' in y:
        yr = y.replace(' ', '')
        df.rename(columns={y: yr}, inplace=True)
    model = smf.ols(formula=f'{yr} ~ {x1r} + {x2r}', data=df)
    results = model.fit()
    results.params

    x_dim, y_dim = np.meshgrid(np.linspace(df[x1r].min(), df[x1r].max(), 100), np.linspace(df[x2r].min(), df[x2r].max(), 100))
    xs = pd.DataFrame({x1r: x_dim.ravel(), x2r: y_dim.ravel()})
    predicted_y = results.predict(exog=xs)
    predicted_y=np.array(predicted_y)

    fig = plt.figure(figsize=size, facecolor='b')
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(df[x1r], df[x2r], df[yr], c='red', marker='o', alpha=0.5)
    ax.plot_surface(x_dim, y_dim, predicted_y.reshape(x_dim.shape), color='b', alpha=0.3)
    ax.set_xlabel(x1label)
    ax.set_ylabel(x2label)
    ax.set_zlabel(ylabel)
    plt.show()

# %%
#variables to study
#teen birth rate
#below poverty level
#unemployment

# 3D Visualization: Regressing Neighborhood on Teen Birth Rate and Unemployment
regression_3d_visualization(dataframe=strong_correlates, x1='Unemployment', x2='Teen Birth Rate', y='Homicide',\
                            size = (10,10), x1label='Unemployment', x2label='Teen Birth Rate (per 1k)',\
                            ylabel='Neighborhood Homicide')

# %%
#Multiple Regression: Regressing Homicide on Teen Birth & Economic Factors

xs = strong_correlates[['Teen Birth Rate', 'Unemployment']]
y = strong_correlates['Homicide']

multiple_regression(xs, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Homicide   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     42.17
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):           5.98e-13
# Time:                        19:57:48   Log-Likelihood:                -378.77
# No. Observations:                  77   AIC:                             763.5
# Df Residuals:                      74   BIC:                             770.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -18.7532      8.620     -2.175      0.033     -35.930      -1.577
# Teen Birth Rate     1.3661      0.197      6.945      0.000       0.974       1.758
# Unemployment       -0.5803      0.786     -0.738      0.463      -2.147       0.986
# ==============================================================================
# Omnibus:                       36.124   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.704
# Skew:                           1.468   Prob(JB):                     4.10e-24
# Kurtosis:                       7.995   Cond. No.                         132.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     36.817293
# 1     41.723164
# 2     -3.353548
# 3     28.463252
# 4     80.729353
#         ...
# 72    37.650318
# 73    64.005773
# 74    17.509928
# 75    44.979209
# 76    41.017021
# Length: 77, dtype: float64

# %%
#Predicted and Actual Homicides based on Teen Birth Rate and Unemployment

predicted_homicides = []

for index, row in strong_correlates.iterrows():
    predicted_value = -18.7532 + 1.3661*row['Teen Birth Rate'] + -0.5803*row['Unemployment']
    predicted_homicides.append(predicted_value)
    

actual_homicides = strong_correlates.Homicide.to_list()
d = pd.read_csv('data/Neighborhood_Health.csv')

# %%
# def actual_vs_predicted(dataframe, index_name, actual_values, predicted_values, chart_size = (8, 6)): #use lists for actual and predicted
#     indices = dataframe.set_index(index_name)
#     x_axis = np.arange(len(actual_values))
#     horizontal_categories = dataframe.index.tolist()
#     tick_locations = [x for x in x_axis]
#     plt.figure(figsize=chart_size)
#     plt.bar(x_axis, dataframe, alpha=0.75, align='center', width=0.55)
#     plt.xticks(tick_locations, horizontal_categories, rotation='vertical')
#     plt.xlim(-0.75,len(x_axis))
#     plt.ylim(0, max(dataframe) + 10)
#     plt.title('Datapoints for each Treatment')
#     plt.xlabel('Drug Regimen')
#     plt.ylabel('Number of Data Points')
#     plt.savefig('../Images/Dps_by_treatment_plt')
#     plt.show()
    
# actual_vs_predicted(strong_correlates, 'Community Area Name', actual_homicides, predicted_homicides)

# %%
#variables to study
#teen birth rate
#below poverty level
#unemployment

# 3D Visualization: Regressing Neighborhood Homicide Rate (per 100k)on Teen Birth Rate and Unemployment
regression_3d_visualization(dataframe=strong_correlates, x1='Unemployment', x2='Teen Birth Rate', y='Homicide_rate_per_100k',\
                            size = (10,10), x1label='Unemployment', x2label='Teen Birth Rate (per 1k)',\
                            ylabel='Neighborhood Homicide_rate_per_100k')

# %%
#Multiple Regression: Regressing Homicide_rate_per_100k on Teen Birth & Economic Factors
xs = strong_correlates[['Teen Birth Rate', 'Unemployment']]
y = strong_correlates['Homicide_rate_per_100k']

multiple_regression(xs, y)
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Homicide_rate_per_100k   R-squared:                       0.735
# Model:                                OLS   Adj. R-squared:                  0.728
# Method:                     Least Squares   F-statistic:                     102.8
# Date:                    Mon, 27 Jul 2020   Prob (F-statistic):           4.37e-22
# Time:                            19:57:57   Log-Likelihood:                -273.72
# No. Observations:                      77   AIC:                             553.4
# Df Residuals:                          74   BIC:                             560.5
# Df Model:                               2
# Covariance Type:                nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -10.1931      2.203     -4.627      0.000     -14.583      -5.804
# Teen Birth Rate     0.2246      0.050      4.467      0.000       0.124       0.325
# Unemployment        1.2792      0.201      6.368      0.000       0.879       1.679
# ==============================================================================
# Omnibus:                       22.591   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.096
# Skew:                           1.082   Prob(JB):                     1.97e-09
# Kurtosis:                       5.795   Cond. No.                         132.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     11.313539
# 1     19.267911
# 2      8.283757
# 3      9.665290
# 4     39.426124
#         ...
# 72     9.800967
# 73    26.779837
# 74     6.627526
# 75     8.531502
# 76    23.413070
# Length: 77, dtype: float64

# %%
#Example prediction equation
t, e = 50.064935 + (2*28.097817), 13.303896 + (2*7.031965)
Neighborhood_Homicide_Rate_Per_100k = -10.1931 + 0.2246*t + 1.2792*e
print(Neighborhood_Homicide_Rate_Per_100k)
#18.068831 + (2*16.561077) = 51.190985
#bar chart (each community will have two bar: one bar is predicted value and other bar is actual)
# Out:
# 48.6819468166

# %%
#Predicted and Actual Homicides based on Teen Birth Rate and Unemployment

predicted_homicide_rate = []

for index, row in strong_correlates.iterrows():
    predicted_value = -10.1931 + 0.2246*row['Teen Birth Rate'] + 1.2792*row['Unemployment']
    predicted_homicide_rate.append(predicted_value)
    

actual_homicide_rate = strong_correlates['Homicide_rate_per_100k'].to_list()
d = pd.read_csv('data/Neighborhood_Health.csv')

# %%
#predicted_homicide_rate
#actual_homicide_rate 
N = len(predicted_homicide_rate) #77
ind = np.arange(N) 
width = 0.35
plt.bar(ind, predicted_homicide_rate, width, label='Predicted (per 100k)')
plt.bar(ind + width, actual_homicide_rate, width, label='Observed (per 100k)')

plt.ylabel('Homidicide Rates')
plt.xlabel('Neighborhoods')
plt.title('Predicted Vs. Observed Homicide Rate (per 100k) by Chicago Neighborhood')

neighborhoods = ()
for i in range(77):
    neighborhoods += ("",)

plt.xticks(ind + width / 2, neighborhoods)
plt.legend(loc='best')
plt.show()

# %%
homicide_rate_per_100k = strong_correlates['Homicide_rate_per_100k']

def outlier_analysis(dfseries):
    q = dfseries.quantile([.25, .5, .75])
    print('\nQuartiles:')
    print(q)

    print('\nInterquartile Range:')
    iqr = q[0.75] - q[0.25]
    print(iqr)

    print('\nOutlier Boundaries:')
    lb = q[0.25] - (1.5*iqr)
    ub = q[0.75] + (1.5*iqr)
    print('Lower = ' + str(lb) + ';', 'Upper = ' + str(ub))

    outlier_values = []
    for rate in dfseries:
        if rate <= lb or rate >= ub:
            outlier_values.append(rate)

    print('\nOutlier Values:')
    if len(outlier_values) == 0:
        print('There are no outlier values.')
    elif len(outlier_values) == 1:
        print(f'There is {len(outlier_values)} outlier value.\nThe outlier value is:')
        print(outlier_values)       
    else:
        print(f'There are {len(outlier_values)} outlier values.\nThe outlier values are:')
        print(outlier_values)
    print()
    print()
    print()
    
outlier_analysis(homicide_rate_per_100k)
outlier_analysis(strong_correlates['Homicide'])
strong_correlates['Homicide'].describe()
# Out:
# Quartiles:
# 0.25     4.9
# 0.50    10.8
# 0.75    32.2
# Name: Homicide_rate_per_100k, dtype: float64
#
# Interquartile Range:
# 27.300000000007596
#
# Outlier Boundaries:
# Lower = -36.05000000001232; Upper = 73.15000000001807
#
# Outlier Values:
# There are no outlier values.
#
#
#
#
# Quartiles:
# 0.25     9.0
# 0.50    21.0
# 0.75    59.0
# Name: Homicide, dtype: float64
#
# Interquartile Range:
# 50.0
#
# Outlier Boundaries:
# Lower = -66.0; Upper = 134.0
#
# Outlier Values:
# There are 5 outlier values.
# The outlier values are:
# [238, 150, 155, 135, 155]
# count     77.000000
# mean      41.922078
# std       48.766837
# min        0.000000
# 25%        9.000000
# 50%       21.000000
# 75%       59.000000
# max      238.000000
# Name: Homicide, dtype: float64

# %%
#Removing outliers

outliers_removed = strong_correlates[strong_correlates.Homicide < 134]
outliers_removed
# Out:
#    Community Area Name  Homicide_rate_per_100k  Homicide  Violence  \
# 0          Albany Park                     4.7        21      6116
# 1       Archer Heights                    16.6         9      1856
# 2        Armour Square                     1.8         5      1886
# 3              Ashburn                    12.4        20      6165
# 4       Auburn Gresham                    37.6       117     23178
# ..                 ...                     ...       ...       ...
# 72           West Lawn                    10.7        15      3800
# 73        West Pullman                    43.9        91     14241
# 74          West Ridge                     5.8        15      7534
# 75           West Town                     8.5        47     15444
# 76            Woodlawn                    31.1        59     13774
#
#     Property Crimes  Breast cancer in females  Cancer (All Sites)  \
# 0              9053                      22.9               158.1
# 1              4547                      25.2               166.3
# 2              4155                      10.7               162.9
# 3             10392                      37.2               229.3
# 4             26566                      41.9               243.0
# ..              ...                       ...                 ...
# 72            10176                      16.9               145.1
# 73            14565                      20.3               263.6
# 74            14923                      20.2               155.9
# 75            40496                      14.5               139.6
# 76            14115                      32.9               241.3
#
#     Colorectal Cancer  Diabetes-related  Lung Cancer  \
# 0                16.8              72.1         36.9
# 1                 9.0              67.7         49.6
# 2                23.1              42.5         54.3
# 3                22.8              80.1         62.8
# 4                24.5              83.6         65.1
# ..                ...               ...          ...
# 72               15.7              61.5         36.7
# 73               32.6              83.4         78.6
# 74               17.3              60.5         36.0
# 75               12.4             107.0         27.4
# 76               23.9              82.1         69.8
#
#     Prostate Cancer in Males  Stroke (Cerebrovascular Disease)  Birth Rate  \
# 0                       13.1                              39.1        18.3
# 1                       20.5                              41.8        18.1
# 2                       17.2                              38.7        11.5
# 3                       44.5                              47.4        14.7
# 4                       43.5                              63.7        15.1
# ..                       ...                               ...         ...
# 72                      19.7                              43.1        18.8
# 73                      62.9                              63.9        15.3
# 74                      14.2                              34.7        17.3
# 75                      16.6                              33.3        18.8
# 76                      58.0                              60.0        15.1
#
#     General Fertility Rate  Low Birth Weight  Preterm Births  Teen Birth Rate  \
# 0                     76.5               8.5             8.3             44.5
# 1                     80.0               8.7            10.0             50.3
# 2                     57.1              12.4            11.8             16.2
# 3                     69.0               9.0            11.3             38.3
# 4                     70.5              11.6            13.9             83.1
# ..                     ...               ...             ...              ...
# 72                    83.3               7.6             8.3             44.6
# 73                    71.2              14.9            14.4             67.8
# 74                    83.3               8.1             8.3             29.9
# 75                    60.4               9.1            10.8             49.2
# 76                    60.1              17.4            16.3             51.1
#
#     Below Poverty Level  Dependency  Unemployment
# 0                  17.1        32.1           9.0
# 1                  13.0        40.5          14.2
# 2                  35.8        37.9          11.6
# 3                   9.5        36.7           8.8
# 4                  24.5        42.1          24.2
# ..                  ...         ...           ...
# 72                 15.3        41.9           7.8
# 73                 24.3        42.2          17.0
# 74                 15.1        38.3           7.9
# 75                 15.7        22.9           6.0
# 76                 28.3        37.6          17.3
#
# [72 rows x 20 columns]

# %%
#Multiple Regression: Regressing Homicide on Teen Birth & Economic Factors

xs = outliers_removed[['Teen Birth Rate', 'Unemployment']]
y = outliers_removed['Homicide']

multiple_regression(xs, y)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Homicide   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     38.20
# Date:                Mon, 27 Jul 2020   Prob (F-statistic):           6.80e-12
# Time:                        19:58:24   Log-Likelihood:                -332.43
# No. Observations:                  72   AIC:                             670.9
# Df Residuals:                      69   BIC:                             677.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -10.0540      6.707     -1.499      0.138     -23.433       3.325
# Teen Birth Rate     1.1009      0.155      7.081      0.000       0.791       1.411
# Unemployment       -0.6615      0.609     -1.087      0.281      -1.876       0.553
# ==============================================================================
# Omnibus:                        5.362   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                4.659
# Skew:                           0.605   Prob(JB):                       0.0973
# Kurtosis:                       3.301   Cond. No.                         126.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     32.982960
# 1     35.928583
# 2      0.107621
# 3     26.289658
# 4     65.423543
#         ...
# 72    33.886806
# 73    53.342275
# 74    17.637396
# 75    40.141590
# 76    34.758768
# Length: 72, dtype: float64

# %%
"""
Limitations:

Correlational and a cross_sectional non-experimental study
Drawing inferences about individuals based on aggregated data (e.g., aggregated at neighborhood and state level)
Well-being measure: 
  need more measures of health factors
  need psychological measures
Need more measures economic measures


Future Directions:

Hierarchical Regression Analysis 
Exploratory Factor Analysis
Individual-level data
Different crime studies (data available)


"""
# Out:
# '\nLimitations:\n\nCorrelational and a cross_sectional non-experimental study\nDrawing inferences about individuals based on aggregated data (e.g., aggregated at neighborhood and state level)\nWell-being measure: \n  need more measures of health factors\n  need psychological measures\nNeed more measures economic measures\n\n\nFuture Directions:\n\nHierarchical Regression Analysis \nExploratory Factor Analysis\nIndividual-level data\nDifferent crime studies (data available)\n\n\n'
