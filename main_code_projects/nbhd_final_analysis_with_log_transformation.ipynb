# %%
# %matplotlib
import gmaps
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import os
import pandas as pd
pd.options.display.max_columns = None
import requests
import time
from scipy.stats import linregress, pearsonr
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import statsmodels.formula.api as smf
#from sklearn.decomposition import FactorAnalysis
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# Variable Units

# Per Capita Income, Birth Rate per (1k),
# General Fertility Rate per (1k),% Low Birth Weight,% Prenatal Care in First Trimester,
# % Preterm Births,Teen Birth Rate per (1k),Homicides per (100k),Breast Cancer Females per (100k),
# Cancer (All Sites) per (100k),Colorectal Cancer per (100k),Diabetes-related per (100k),Firearm-related per (100k),
# Infant Mortality Rate per (1k),Lung Cancer per (100k),Prostate Cancer in Males per (100k),
# Stroke (Cerebrovascular Disease) per (100k),Childhood Blood Lead Level Screening per (1k),
# Childhood Lead Poisoning per (100),Gonorrhea in Females per (100k),Gonorrhea in Males per (100k),
# Tuberculosis per (100k),% Below Poverty Level,% Crowded Housing,% Dependency,% No High School Diploma,Unemployment

# %%
# Final analysis data

final_df = pd.read_csv('output_data/analysis_data.csv')
# 77 rows × 20 columns

# %%
final_df.columns
# Out:
# Index(['Community Area Name', 'Homicide_rate_per_100k', 'Homicide', 'Violence',
#        'Property Crimes', 'Breast cancer in females', 'Cancer (All Sites)',
#        'Colorectal Cancer', 'Diabetes-related', 'Lung Cancer',
#        'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)',
#        'Birth Rate', 'General Fertility Rate', 'Low Birth Weight',
#        'Preterm Births', 'Teen Birth Rate', 'Below Poverty Level',
#        'Dependency', 'Unemployment'],
#       dtype='object')

# %%
health_factors = final_df[['Homicide_rate_per_100k', 'Breast cancer in females', 'Cancer (All Sites)',
       'Colorectal Cancer', 'Diabetes-related', 'Lung Cancer', 'Prostate Cancer in Males', 'Stroke (Cerebrovascular Disease)']]

health_factors.columns = ['Homicide (per 100k)', 'Breast Cancer', 'Cancer (All Sites)', 'Colorectal Cancer',\
                                 'Diabetes-related', 'Lung Cancer', 'Prostate Cancer', 'Stroke']

health_factors.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col3 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col4 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col6 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow0_col7 {
#             background-color:  #1e80b8;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col0 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col1 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col3 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col4 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col5 {
#             background-color:  #045e94;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col6 {
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow2_col7 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col0 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col1 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col2 {
#             background-color:  #569dc8;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col4 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col5 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col6 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow3_col7 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col0 {
#             background-color:  #63a2cb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col2 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col3 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col5 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col6 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow4_col7 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col0 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col1 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col2 {
#             background-color:  #056ba9;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col3 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col4 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col6 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow5_col7 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col0 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col1 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col2 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col3 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col4 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col5 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow6_col7 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow7_col0 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow7_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow7_col2 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_f3fa7f74_d10f_11ea_a149_484520bb7f9brow7_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;

# %%
birth_factors = final_df[['Homicide_rate_per_100k',
       'Birth Rate', 'General Fertility Rate', 'Low Birth Weight',
       'Preterm Births', 'Teen Birth Rate']].reset_index(drop=True)


birth_factors.rename(columns={'Homicide_rate_per_100k': 'Homicide (per 100k)'}, inplace=True)

birth_factors.corr()
# Out:
#                         Homicide (per 100k)  Birth Rate  \
# Homicide (per 100k)                1.000000    0.188536
# Birth Rate                         0.188536    1.000000
# General Fertility Rate             0.293843    0.810334
# Low Birth Weight                   0.747493    0.108179
# Preterm Births                     0.742019    0.004334
# Teen Birth Rate                    0.768307    0.612710
#
#                         General Fertility Rate  Low Birth Weight  \
# Homicide (per 100k)                   0.293843          0.747493
# Birth Rate                            0.810334          0.108179
# General Fertility Rate                1.000000          0.142189
# Low Birth Weight                      0.142189          1.000000
# Preterm Births                        0.122235          0.843100
# Teen Birth Rate                       0.655528          0.622936
#
#                         Preterm Births  Teen Birth Rate
# Homicide (per 100k)           0.742019         0.768307
# Birth Rate                    0.004334         0.612710
# General Fertility Rate        0.122235         0.655528
# Low Birth Weight              0.843100         0.622936
# Preterm Births                1.000000         0.549843
# Teen Birth Rate               0.549843         1.000000

# %%
economic_factors = final_df[['Homicide_rate_per_100k','Below Poverty Level','Dependency', 'Unemployment']].reset_index(drop=True)
economic_factors.rename(columns={'Homicide_rate_per_100k': 'Homicide (per 100k)'}, inplace=True)
economic_factors.corr().corr().style.background_gradient('BrBG')
# Out:
# <style  type="text/css" >
#     #T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col0 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col1 {
#             background-color:  #d4ede9;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col2 {
#             background-color:  #d3aa5f;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col3 {
#             background-color:  #61b7ac;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col0 {
#             background-color:  #f6ebcd;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col1 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col2 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col3 {
#             background-color:  #8fd3c9;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col0 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col1 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col2 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col3 {
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col0 {
#             background-color:  #70c1b6;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col1 {
#             background-color:  #61b7ac;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col2 {
#             background-color:  #bf812d;
#             color:  #000000;
#         }    #T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col3 {
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }</style><table id="T_f4048aba_d10f_11ea_8076_484520bb7f9b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Homicide (per 100k)</th>        <th class="col_heading level0 col1" >Below Poverty Level</th>        <th class="col_heading level0 col2" >Dependency</th>        <th class="col_heading level0 col3" >Unemployment</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4048aba_d10f_11ea_8076_484520bb7f9blevel0_row0" class="row_heading level0 row0" >Homicide (per 100k)</th>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col1" class="data row0 col1" >0.166107</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col2" class="data row0 col2" >-0.441106</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow0_col3" class="data row0 col3" >0.596215</td>
#             </tr>
#             <tr>
#                         <th id="T_f4048aba_d10f_11ea_8076_484520bb7f9blevel0_row1" class="row_heading level0 row1" >Below Poverty Level</th>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col0" class="data row1 col0" >0.166107</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col2" class="data row1 col2" >-0.954319</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow1_col3" class="data row1 col3" >0.494276</td>
#             </tr>
#             <tr>
#                         <th id="T_f4048aba_d10f_11ea_8076_484520bb7f9blevel0_row2" class="row_heading level0 row2" >Dependency</th>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col0" class="data row2 col0" >-0.441106</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col1" class="data row2 col1" >-0.954319</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow2_col3" class="data row2 col3" >-0.562269</td>
#             </tr>
#             <tr>
#                         <th id="T_f4048aba_d10f_11ea_8076_484520bb7f9blevel0_row3" class="row_heading level0 row3" >Unemployment</th>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col0" class="data row3 col0" >0.596215</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col1" class="data row3 col1" >0.494276</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col2" class="data row3 col2" >-0.562269</td>
#                         <td id="T_f4048aba_d10f_11ea_8076_484520bb7f9brow3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# Function for Simple Regression

# Features: plots line, provides stats, describes relationship

def regression(x, y, x_label, y_label):
    title = f'{x_label} predicting {y_label}'
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    title = title.replace('\n', '_').replace(' ', '_')
    plt.savefig(f'output_data/{title}.png')
    plt.show()
    #plt.close()
    print(line_eq)
    print()
    r = pearsonr(x, y)[0]
    p = pearsonr(x, y)[1]
    print(f"r = {r:.2f}, p = {p:.4f}, r_squared = {rvalue**2:.2f}")
    print()
    if p > 0.05:
        print(f'There is no relationship between {x_label.lower()} and {y_label.lower()}, p > 0.05.')
    else:
        if r > 0:
            explanation = f'An increase in {x_label.lower()} is associated with an increase in {y_label.lower()}.'
            direction = 'positive'
            if r >= 0.6:
                strength = 'strong'
            elif r >= 0.3:
                strength = 'moderate'
            else:
                strength = 'weak'
        else:
            direction = 'negative'
            explanation = f'An increase in {x_label.lower()} is associated with a decrease in {y_label.lower()}.'
            if r <= -0.6:
                strength = 'strong'
            elif r <= -0.3:
                strength = 'moderate'
            else:
                strength = 'weak'       
        print(f'There is a {strength} {direction} relationship between {x_label.lower()} and {y_label.lower()}, p > 0.05.')
        print(explanation)
    print()

# %%
# Multiple Regression Function

# Features: Provides stats and statistical model test

def multiple_regression(xs, y): # xs is a dataframe, y is a series; prints output and returns predictions
    xs = sm.add_constant(xs) # adding a constant
    model = sm.OLS(y, xs).fit()
    predictions = model.predict(xs) 
    print_model = model.summary()
    print(print_model)
    return predictions

# %%
# 3D Visualization of Multiple Regression Function
def regression_3d_visualization(dataframe, x1, x2, y, size = (10,10), x1label='X Label', x2label='Y Label', ylabel='Z Label'):
    df = dataframe[[x1, x2, y]].reset_index(drop=True)
    x1r, x2r, yr = x1, x2, y
    if ' ' in x1:
        x1r = x1.replace(' ', '')
        df.rename(columns={x1: x1r}, inplace=True)
    if ' ' in x2:
        x2r = x2.replace(' ', '')
        df.rename(columns={x2: x2r}, inplace=True)
    if ' ' in y:
        yr = y.replace(' ', '')
        df.rename(columns={y: yr}, inplace=True)
    model = smf.ols(formula=f'{yr} ~ {x1r} + {x2r}', data=df)
    results = model.fit()
    results.params

    x_dim, y_dim = np.meshgrid(np.linspace(df[x1r].min(), df[x1r].max(), 100), np.linspace(df[x2r].min(), df[x2r].max(), 100))
    xs = pd.DataFrame({x1r: x_dim.ravel(), x2r: y_dim.ravel()})
    predicted_y = results.predict(exog=xs)
    predicted_y=np.array(predicted_y)

    fig = plt.figure(figsize=size, facecolor='b')
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(df[x1r], df[x2r], df[yr], c='red', marker='o', alpha=0.5)
    ax.plot_surface(x_dim, y_dim, predicted_y.reshape(x_dim.shape), color='b', alpha=0.3)
    ax.set_xlabel(x1label)
    ax.set_ylabel(x2label)
    ax.set_zlabel(ylabel)
    plt.show()

# %%
#Regressing neighborhood homicide rate (per 1k) on the teen birth rate (per 1k).

#regression(x, y, x_label, y_label)

regression(final_df['Teen Birth Rate'], final_df['Homicide_rate_per_100k'], 'Teen Birth Rate (per 1k)', 'Neighborhood Homicide Rate (per 100k)')
# Out:
# y = 0.0x + -0.05
#
# r = 0.77, p = 0.0000, r_squared = 0.59
#
# There is a strong positive relationship between teen birth rate (per 1k) and neighborhood homicide rate (per 1k), p > 0.05.
# An increase in teen birth rate (per 1k) is associated with an increase in neighborhood homicide rate (per 1k).

# %%
#Regressing neighborhood homicide rate (per 100k) on Unemployment (%)

#regression(x, y, x_label, y_label)

regression(final_df['Unemployment'], final_df['Homicide_rate_per_100k'], 'Unemployment (%)', 'Neighborhood Homicide Rate (per 100k)')
# Out:
# y = 1.92x + -7.46
#
# r = 0.81, p = 0.0000, r_squared = 0.66
#
# There is a strong positive relationship between unemployment (%) and neighborhood homicide rate (per 100k), p > 0.05.
# An increase in unemployment (%) is associated with an increase in neighborhood homicide rate (per 100k).

# %%
#Multiple Regression: Regressing Homicide_rate_per_100k on Teen Birth & Economic Factors
xs = final_df[['Teen Birth Rate', 'Unemployment']]
y = final_df['Homicide_rate_per_100k']

multiple_regression(xs, y)

#Note the statistically significant Kurtosis
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Homicide_rate_per_100k   R-squared:                       0.735
# Model:                                OLS   Adj. R-squared:                  0.728
# Method:                     Least Squares   F-statistic:                     102.8
# Date:                    Tue, 28 Jul 2020   Prob (F-statistic):           4.37e-22
# Time:                            15:21:45   Log-Likelihood:                -273.72
# No. Observations:                      77   AIC:                             553.4
# Df Residuals:                          74   BIC:                             560.5
# Df Model:                               2
# Covariance Type:                nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -10.1931      2.203     -4.627      0.000     -14.583      -5.804
# Teen Birth Rate     0.2246      0.050      4.467      0.000       0.124       0.325
# Unemployment        1.2792      0.201      6.368      0.000       0.879       1.679
# ==============================================================================
# Omnibus:                       22.591   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.096
# Skew:                           1.082   Prob(JB):                     1.97e-09
# Kurtosis:                       5.795   Cond. No.                         132.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     11.313539
# 1     19.267911
# 2      8.283757
# 3      9.665290
# 4     39.426124
#         ...
# 72     9.800967
# 73    26.779837
# 74     6.627526
# 75     8.531502
# 76    23.413070
# Length: 77, dtype: float64

# %%
#teen birth rate
#below poverty level
#unemployment

# 3D Visualization: Regressing Neighborhood Homicide Rate (per 100k)on Teen Birth Rate and Unemployment
regression_3d_visualization(dataframe=final_df, x1='Unemployment', x2='Teen Birth Rate', y='Homicide_rate_per_100k',\
                            size = (10,10), x1label='Unemployment', x2label='Teen Birth Rate (per 1k)',\
                            ylabel='Neighborhood Homicide_rate_per_100k')

# %%
#Example prediction equation
t, e = 50.064935 + (2*28.097817), 13.303896 + (2*7.031965)
Neighborhood_Homicide_Rate_Per_100k = -10.1931 + 0.2246*t + 1.2792*e
print(Neighborhood_Homicide_Rate_Per_100k)
#18.068831 + (2*16.561077) = 51.190985
# Out:
# 48.6819468166

# %%
#Predicted and Actual Homicides based on Teen Birth Rate and Unemployment

predicted_homicide_rate = []

for index, row in final_df.iterrows():
    predicted_value = -10.1931 + 0.2246*row['Teen Birth Rate'] + 1.2792*row['Unemployment']
    predicted_homicide_rate.append(predicted_value)
    

actual_homicide_rate = final_df['Homicide_rate_per_100k'].to_list()

# %%
#predicted_homicide_rate
#actual_homicide_rate 
N = len(predicted_homicide_rate) #77
ind = np.arange(N) 
width = .35
f, ax = plt.subplots(figsize=(8.5,3.5))
plt.bar(ind, predicted_homicide_rate, width, label='Predicted (per 100k)')
plt.bar(ind + width, actual_homicide_rate, width, label='Observed (per 100k)')

plt.ylabel('Homidicide Rates (per 100k)')
plt.xlabel('Neighborhoods (n = 77)')
plt.title('Predicted vs. Observed Homicide Rate for each Chicago Neighborhood')
neighborhoods = ()
for i in range(77):
    neighborhoods += ("",)

plt.xticks(ind + width / 2, neighborhoods)
plt.legend(loc='best')
plt.show()

# %%
"""
Limitations:

Correlational and a cross_sectional non-experimental study
Drawing inferences about individuals based on aggregated data (e.g., aggregated at neighborhood and state level)
Well-being measure: 
  need more measures of health factors
  need psychological measures
  Need more measures economic measures

Non-normality of outcome variable

Future Directions:

Hierarchical Regression Analysis 
Exploratory Factor Analysis
Individual-level data

"""
# Out:
# '\nLimitations:\n\nCorrelational and a cross_sectional non-experimental study\nDrawing inferences about individuals based on aggregated data (e.g., aggregated at neighborhood and state level)\nWell-being measure: \n  need more measures of health factors\n  need psychological measures\n  Need more measures economic measures\n\nNon-normality of outcome variable\n\nFuture Directions:\n\nHierarchical Regression Analysis \nExploratory Factor Analysis\nIndividual-level data\n\n'

# %%
final_df['Homicide_rate_per_100k'].hist(bins=20)

# %%
#log transformation + constant to make homicide variable more normally distributed
final_df['Homicide_rate_log'] = final_df['Homicide_rate_per_100k'].apply(lambda x: np.log(x+1))

# %%
final_df['Homicide_rate_log'].hist(bins=20)

# %%
#log units

#Regressing neighborhood homicide rate (per 100k) on the teen birth rate (per 1k).

#regression(x, y, x_label, y_label)

regression(final_df['Teen Birth Rate'], final_df['Homicide_rate_log'], 'Teen Birth Rate (per 1k)', 'Log Units - Homicide Rate')
# Out:
# y = 0.03x + 1.05
#
# r = 0.83, p = 0.0000, r_squared = 0.68
#
# There is a strong positive relationship between teen birth rate (per 1k) and log units - homicide rate, p > 0.05.
# An increase in teen birth rate (per 1k) is associated with an increase in log units - homicide rate.

# %%
#log units

#Regressing neighborhood homicide rate (per 100k) on the Unemployment Rate.

#regression(x, y, x_label, y_label)

regression(final_df['Unemployment'], final_df['Homicide_rate_log'], 'Unemployment (%)', 'Log Units - Homicide Rate')
# Out:
# y = 0.11x + 1.02
#
# r = 0.79, p = 0.0000, r_squared = 0.63
#
# There is a strong positive relationship between unemployment (%) and log units - homicide rate, p > 0.05.
# An increase in unemployment (%) is associated with an increase in log units - homicide rate.

# %%
#Log Units

#Multiple Regression: Regressing Homicide_rate_per_100k on Teen Birth & Economic Factors
xs = final_df[['Teen Birth Rate', 'Unemployment']]
y = final_df['Homicide_rate_log']

multiple_regression(xs, y)

#No more statistically significant kurtosis.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Homicide_rate_log   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     122.7
# Date:                Tue, 28 Jul 2020   Prob (F-statistic):           3.14e-24
# Time:                        15:56:33   Log-Likelihood:                -52.148
# No. Observations:                  77   AIC:                             110.3
# Df Residuals:                      74   BIC:                             117.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.7939      0.124      6.405      0.000       0.547       1.041
# Teen Birth Rate     0.0189      0.003      6.665      0.000       0.013       0.024
# Unemployment        0.0587      0.011      5.190      0.000       0.036       0.081
# ==============================================================================
# Omnibus:                        1.124   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.570   Jarque-Bera (JB):                1.194
# Skew:                          -0.262   Prob(JB):                        0.550
# Kurtosis:                       2.688   Cond. No.                         132.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     2.160981
# 1     2.575383
# 2     1.779882
# 3     2.032343
# 4     3.780465
#         ...
# 72    2.092473
# 73    3.069611
# 74    1.821159
# 75    2.073619
# 76    2.772318
# Length: 77, dtype: float64

# %%
#Log units

#teen birth rate
#below poverty level
#unemployment

# 3D Visualization: Regressing Neighborhood Homicide Rate (per 100k)on Teen Birth Rate and Unemployment
regression_3d_visualization(dataframe=final_df, x1='Unemployment', x2='Teen Birth Rate', y='Homicide_rate_log',\
                            size = (10,10), x1label='Unemployment', x2label='Teen Birth Rate (per 1k)',\
                            ylabel='Neighborhood Homicide Rate in Log Units')
